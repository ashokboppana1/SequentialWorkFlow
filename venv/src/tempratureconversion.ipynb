# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict,NotRequired

# %%
class TempratureState(TypedDict):
    temp_celcius:float
    temp_faranhit:float
    weather_status: NotRequired[str]

# %%
def convert_temprature(state:TempratureState) ->TempratureState:
    celcius=state['temp_celcius']
    farahit=(celcius*1.8)+32
    state['temp_faranhit']=round(farahit,2)
    return state

# %%
def labelweaather(state:TempratureState) -> TempratureState:
    if state['temp_faranhit']>=50:
        state['weather_status']=='hot'
    elif state['temp_faranhit']>=25:
     state['weather_status']=='noraml'
    elif state['temp_faranhit']>=75:
          state['weather_status']=='hot'
    return state

# %%
graph=StateGraph(TempratureState)
graph.add_node('converttemprature',convert_temprature)
graph.add_node('laveltemprature',labelweaather)
graph.add_edge(START,'converttemprature')
graph.add_edge('converttemprature','laveltemprature')
graph.add_edge('laveltemprature',END)

# %%
braphbuild=graph.compile()

# %%
intialstate={'temp_celcius':54.8}
final_state=braphbuild.invoke(intialstate)
print(final_state)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 2
#       1 intialstate={'temp_celcius':54.8}
# ----> 2 final_state=braphbuild.invoke(intialstate)
#       3 print(final_state)
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\pregel\main.py:3913, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3910             chunks.append(chunk)
#    3911 else:
#    3912     # v1: collect interrupts from updates stream
# -> 3913     for chunk in self.stream(
#    3914         input,
#    3915         config,
#    3916         context=context,
#    3917         stream_mode=(
#    3918             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3919         ),
#    3920         print_mode=print_mode,
#    3921         output_keys=output_keys,
#    3922         interrupt_before=interrupt_before,
#    3923         interrupt_after=interrupt_after,
#    3924         durability=durability,
#    3925         control=control,
#    3926         **kwargs,
#    3927     ):
#    3928         if stream_mode == "values":
#    3929             if len(chunk) == 2:
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\pregel\main.py:2967, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2965 for task in loop.match_cached_writes():
#    2966     loop.output_writes(task.id, task.writes, cached=True)
# -> 2967 for _ in runner.tick(
#    2968     [t for t in loop.tasks.values() if not t.writes],
#    2969     timeout=self.step_timeout,
#    2970     get_waiter=get_waiter,
#    2971     schedule_task=loop.accept_push,
#    2972 ):
#    2973     # emit output
#    2974     yield from _output(
#    2975         stream_mode,
#    2976         print_mode,
#    (...)   2982         _state_mapper,
#    2983     )
#    2984 loop.after_tick()
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\pregel\_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\_internal\_runnable.py:707, in RunnableSeq.invoke(self, input, config, **kwargs)
#     705     # run in context
#     706     with set_config_context(config, run) as context:
# --> 707         input = context.run(step.invoke, input, config, **kwargs)
#     708 else:
#     709     input = step.invoke(input, config)
#
# File ~\Desktop\GenAI\SequentialWorkFlow\venv\Lib\site-packages\langgraph\_internal\_runnable.py:447, in RunnableCallable.invoke(self, input, config, **kwargs)
#     445         run_manager.on_chain_end(ret)
#     446 else:
# --> 447     ret = self.func(*args, **kwargs)
#     448 if self.recurse and isinstance(ret, Runnable):
#     449     return ret.invoke(input, config)
#
# Cell In[16], line 3, in labelweaather(state)
#       1 def labelweaather(state:TempratureState) -> TempratureState:
#       2     if state['temp_faranhit']>=50:
# ----> 3         state['weather_status']=='hot'
#       4     elif state['temp_faranhit']>=25:
#       5      state['weather_status']=='noraml'
#       6     elif state['temp_faranhit']>=75:
#
# KeyError: 'weather_status'
# During task with name 'laveltemprature' and id 'ce9e84f0-0d76-a62c-f27b-8c992adae115'

# %% [markdown]
# Visualize grpah

# %%
from IPython.display import Image
Image(braphbuild.get_graph().draw_mermaid_png())
